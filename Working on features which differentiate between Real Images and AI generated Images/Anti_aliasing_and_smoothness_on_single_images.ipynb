# %% [markdown]
# **Anti-Aliasing in AI-Generated Images**

# %% [markdown]
# *   AI-generated images (especially from models like GANs or diffusion models) are created from patterns learned from training data, rather than through natural optics.
# *   Many models apply some form of anti-aliasing to simulate smooth transitions, but this is often imperfect, especially in high-frequency areas where sharp details or textures are expected.
#
# *   Generated images may appear overly smooth or unnaturally blended, especially around fine details like hair, fabric, or intricate patterns. This smoothness can look unrealistic, particularly when contrasted with the subtle imperfections in real images.

# %%
import cv2
import matplotlib.pyplot as plt

def display_edges(image_path):
    # Load the image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Apply a Canny edge detector
    edges = cv2.Canny(image, 100, 200)

    # Display the original and edge-detected images
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(image, cmap='gray')
    plt.title("Original Image")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(edges, cmap='gray')
    plt.title("Edge Detection (Canny)")
    plt.axis("off")

    plt.show()

# %%
import matplotlib.pyplot as plt
import cv2

# Function to display an image
def display_image(image_path, title="Image"):
    # Load the image
    image = cv2.imread(image_path)
    # Convert BGR (OpenCV default) to RGB for correct color display
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Display the image
    plt.imshow(image)
    plt.axis('off')  # Hide axes
    plt.title(title)
    plt.show()

# %% [markdown]
# Real Images

# %%
image_path = "/content/real 4.jpg"  # Replace with your image path

# Display the image
display_image(image_path, title="Displayed Image")

display_edges(image_path)

# %%
image_path = "/content/real 5.jpg"  # Replace with your image path

# Display the image
display_image(image_path, title="Displayed Image")

display_edges(image_path)

# %% [markdown]
# Fake Images

# %%
image_path = "/content/fake 1.png"

# Display the image
display_image(image_path, title="Displayed Image")

display_edges(image_path)

# %%
image_path = "/content/fake 2.png"  # Replace with your image path

# Display the image
display_image(image_path, title="Displayed Image")

display_edges(image_path)

# %% [markdown]
# The above real images showed more edges as compared to fake imaegs
#
#
# We can consider edge-detection and smoothning as a factor to differentiate between AI-generated image and real image
